# %% [markdown]
# Goal: Communicate insights clearly to stakeholders who need them. Methods:
#
# · Executive summaries
# · Alerts
# . Detailed technical reports
# . Recommendations for SOC teams, security leaders, or IT teams
#
# Example:
#
# · Summaries showing exposed credentials, vulnerable endpoints, and required mitigation steps
# . Alerts about active exploitation of a critical CVE affecting the organization

# %% [markdown]
# # 📢 **DISSEMINATION: DEFENSIVE RECOMMENDATIONS**
#
# This phase translates everything we discovered in **Google Dorking**, **Hunter.io**, **theHarvester**, **crt.sh**, **HaveIBeenPwned**, **Shodan**, and **MalwareBazaar** into **clear defensive actions** for security teams and decision-makers.
#
# The goal is simple:
#
# 👉 **Turn raw intelligence into practical security improvements.**
# 👉 **Show exactly how an attacker would exploit what we found.**
# 👉 **Give concrete steps to shut down these attack paths.**
#
# ---
#
# # 🧱 **1. Google Dorking Findings → Defensive Actions**
#
# Google Dorking revealed **indexable pages**, **error messages**, **misconfigured systems**, **staff exposure**, and **architecture hints**.
# Every single one of these is an entry point for an attacker.
#
# ## 🔍 1.1 What we saw
#
# Using dorks like:
#
# ```
# site:nhs.uk "error" OR "exception" OR "warning"
# site:*.nhs.uk "index of"
# site:nhs.uk "password"
# site:nhs.uk "login"
# site:nhs.uk "backup"
# ```
#
# We observed:
#
# ### ✔ Error messages with:
#
# * Tech stack names (PHP, ASP.NET, Nginx)
# * API endpoint paths
# * Version numbers
# * Internal server behaviors
#
# **Why attackers care:**
# Error messages act like **breadcrumbs**—they tell attackers exactly where systems break and what can be exploited.
#
# ### ✔ Directory listings (“index of /”)
#
# Often reveal:
#
# * Logs
# * Backups
# * Configuration files
# * Staff uploads
# * Scripts
#
# **These were likely never meant to be public.**
#
# ### ✔ Exposed staff information
#
# Google indexed:
#
# * Staff names
# * Department structures
# * Email patterns
# * Teams pages
# * Clinical / administrative contacts
#
# This enables:
#
# * Spear-phishing
# * Identity spoofing
# * Social engineering
#
# ---
#
# ## 🛡 1.2 Defensive Recommendations
#
# ### 🧼 **A. Sanitise all web error messages**
#
# Replace verbose errors with generic messages:
#
# ❌ *“Warning: db_connect() failed on line 83”*
# ✔ *“An internal error occurred.”*
#
# This prevents attackers from discovering:
#
# * Database engines
# * File paths
# * Code flaws
# * Stack details
#
# ---
#
# ### 🔒 **B. Enforce strict indexing policies**
#
# Implement:
#
# * `robots.txt`
# * `.htaccess` directory listing blocks
# * “noindex” headers on internal/admin pages
#
# Purpose:
# 👉 Stop sensitive pages from appearing on Google.
#
# ---
#
# ### 🔏 **C. Perform scheduled external surface scans**
#
# Weekly scans using:
#
# * Gitleaks
# * nikto
# * dirsearch
# * Burp passive crawl
#
# The objective:
# 👉 Know exactly what the public can see—before attackers do.
#
# ---
#
# ### 🎭 **D. Obfuscate internal staff structures**
#
# Limit publicly visible:
#
# * Staff directories
# * Organizational charts
# * Non-essential emails
#
# This reduces spear-phishing surface.
#
# ---
#
# ---
#
# # 📨 **2. Hunter.io & theHarvester Findings → Defensive Actions**
#
# Hunter.io + theHarvester revealed **valid email patterns**, **positions**, **names**, and **organizational units**.
#
# Attackers use this to:
#
# * Build targeted phishing lists
# * Validate which emails exist
# * Identify high-value individuals (CFO, HR, Procurement)
# * Plan credential stuffing
# * Launch BEC attacks
#
# ---
#
# ## 🧷 2.1 What we saw
#
# * Clear email format:
#   `firstname.lastname@nhs.uk`
# * Hundreds of discoverable staff emails
# * Some emails cross-referenced in breached datasets
# * Legacy emails still discoverable
#
# This creates **direct phishing risk**.
#
# ---
#
# ## 🛡 2.2 Defensive Recommendations
#
# ### 🔐 A. Enforce MFA for all decision makers
#
# Especially:
#
# * Budget approvers
# * Executives
# * HR
# * Procurement
# * IT admins
#
# Attackers *will* target them first.
#
# ---
#
# ### 📨 B. Minimise generic mailboxes
#
# Generic inboxes like:
#
# * enquiries@
# * finance@
# * admin@
#
# → Are prime spear-phishing entry points
# → Lack accountability
# → Often have weak passwords
# → Can be brute-forced silently
#
# **Recommendation:**
#
# * Replace with aliases linked to named accounts
# * Log all access and changes
# * Enforce MFA
#
# ---
#
# ### 🎯 C. Run targeted phishing simulations
#
# Focus on the most abused roles:
#
# * C-suite
# * Finance
# * HR
# * Procurement
# * IT help desk
#
# Attackers ALWAYS simulate:
#
# * Invoice fraud
# * HR document scams
# * MFA reset scams
#
# So you must simulate them too.
#
# ---
#
# ### 👁‍🗨 D. Monitor for newly discovered staff emails
#
# Setup:
#
# * Weekly Hunter.io scans
# * Monthly theHarvester sweeps
# * Alerts when new emails appear online
#
# Goal:
# 👉 Detect staff who unknowingly leaked their work email on personal sites, PDFs, public docs, or social media.
#
# ---
#
# ---
#
# # 🔐 **3. Crt.sh (Certificate Transparency) → Defensive Actions**
#
# Cert transparency analysis showed:
#
# * Subdomains that do NOT appear on the main site
# * Test environments
# * Legacy systems
# * Forgotten portals
# * Admin dashboards
# * API endpoints
#
# Attackers use CT logs because CT = “treasure map of hidden systems”.
#
# ---
#
# ## 🛡 Defensive Recommendations
#
# ### 🧹 A. Inventory & decommission unknown subdomains
#
# Example items that often show up:
#
# * dev-api.nhs.uk
# * test-mail.nhs.uk
# * admin-portal.nhs.uk
# * old-vpn.nhs.uk
#
# Each one is:
#
# → A potential vulnerability
# → Often unpatched
# → Frequently forgotten
# → A common entry point for ransomware affiliates
#
# ---
#
# ### ⛓ B. Enforce certificate hygiene
#
# Ensure:
#
# * No expired certs
# * No self-signed certs
# * No public certs on internal systems
# * Remove certs for decommissioned domains
#
# This prevents:
#
# * MITM
# * Domain takeover
# * Spoofed services
#
# ---
#
# ---
#
# # 🧬 **4. HaveIBeenPwned Findings → Defensive Actions**
#
# HIBP showed:
#
# * Emails from NHS-related domains appear in multiple breaches
# * Some breaches contain **plaintext passwords**
# * Several addresses reappear across multiple incidents
#
# This is GOLD for attackers.
#
# HIBP answers three attacker questions:
#
# 1. **Does the email exist?** → Yes
# 2. **Has it been breached?** → Yes
# 3. **Does it contain a password?** → Yes—sometimes plaintext
#
# This creates **credential stuffing** and **phishing amplification** risk.
#
# ---
#
# ## 🛡 Defensive Recommendations
#
# ### 🔐 A. Reset all passwords immediately
#
# Across:
#
# * Office 365
# * NHS SSO
# * Any clinical portal
# * VPN
# * Procurement portals
#
# If one password leaked → attackers *will* test it on all systems.
#
# ---
#
# ### 🔑 B. Enforce unique passwords
#
# Never reuse a password on:
#
# * Personal accounts
# * Work email
# * Admin systems
#
# HIBP breaches often reveal reused passwords.
#
# ---
#
# ### 🔒 C. Enable MFA everywhere
#
# MFA stops:
#
# * Password stuffing
# * Stolen password reuse
# * Automated bots
#
# Even if the password leaked, MFA blocks 90%+ attacks.
#
# ---
#
# ### 👁 D. Monitor inbox rules
#
# Attackers who compromise email accounts IMMEDIATELY create:
#
# * Auto-delete rules
# * Hidden folder rules
# * Forwarding rules to outside addresses
#
# These rules = long-term persistence.
#
# ---
#
# ### 🔔 E. Subscribe to HIBP monitoring
#
# So that future breaches trigger instant notifications.
#
# ---
#
# ---
#
# # 🌐 **5. Shodan Findings → Defensive Actions**
#
# Shodan revealed:
#
# * Public-facing MySQL ports
# * Open RDP
# * Exposed VPN portals
# * Potentially outdated web servers
# * SSH accessible from anywhere
#
# Each exposed port = one attack vector.
#
# ---
#
# ## 🛡 Defensive Recommendations
#
# ### 🔥 A. Firewall critical services (MySQL, RDP, SSH)
#
# Expose ONLY through:
#
# * VPN
# * Bastion host
# * Zero Trust access
#
# Never directly open:
#
# * Port 3306 (MySQL)
# * Port 3389 (RDP)
# * Port 22 (SSH)
#
# ---
#
# ### 🧨 B. Patch exposed systems aggressively
#
# Anything visible on Shodan must be:
#
# * Patched
# * Hardened
# * Monitored
#
# Attackers constantly scan Shodan IP lists.
#
# ---
#
# ### 🛑 C. Block brute-force behavior
#
# Implement:
#
# * Fail2Ban
# * Geo-fencing
# * Rate limits
# * IP reputation filtering
#
# ---
#
# ---
#
# # 🧫 **6. MalwareBazaar Findings → Defensive Actions**
#
# MalwareBazaar helps identify:
#
# * Malware samples impersonating NHS
# * NHS-themed PDFs, lures, invoices
# * Ransomware loaders
# * Qilin-related samples
# * Malware referencing *.nhs.uk in strings or infrastructure
#
# This shows what attackers *currently* use to target healthcare.
#
# ---
#
# ## 🛡 Defensive Recommendations
#
# ### 🧪 A. Implement IOC-based detection
#
# Extract from malware:
#
# * Hashes
# * Domains
# * IPs
# * Paths
# * Mutex names
#
# Push these IOCs into:
#
# * EDR
# * SIEM
# * DNS filters
# * Firewall blocklists
#
# ---
#
# ### 🩺 B. Train staff using real attacker lures
#
# Use real-but-sanitized NHS-themed phishing lures discovered in samples.
#
# Example:
#
# * Fake appointment reminders
# * Test result notifications
# * Fake invoice attachments
#
# ---
#
# ### 🚨 C. Watch for malware families known to target NHS-type orgs
#
# Particularly:
#
# * Qilin
# * LockBit
# * ALPHV
# * Royal
# * Conti
#
# Map these to MITRE to prepare defenses.
#
# ---
#
# ---
#
# # 🧱 **7. Final Summary of Defensive Recommendations**
#
# Below is the complete, consolidated list:
#
# ## **A. Password & Identity Controls**
#
# ✔ Reset all passwords
# ✔ Unique passwords
# ✔ Mandatory MFA
# ✔ Monitor inbox rules
#
# ---
#
# ## **B. Email Security**
#
# ✔ DMARC, SPF, DKIM
# ✔ Minimize generic mailboxes
# ✔ Targeted phishing simulations
#
# ---
#
# ## **C. External Attack Surface**
#
# ✔ Remove indexable internal pages
# ✔ Sanitize error messages
# ✔ Remove directory listings
# ✔ Patch exposed services
# ✔ Firewall critical ports
#
# ---
#
# ## **D. Staff Exposure**
#
# ✔ Reduce public staff directories
# ✔ Monitor Hunter.io and theHarvester results
# ✔ Train high-risk departments
#
# ---
#
# ## **E. Certificate Transparency**
#
# ✔ Inventory revealed subdomains
# ✔ Remove abandoned systems
# ✔ Enforce proper TLS lifecycle
#
# ---
#
# ## **F. Threat Intel Integration**
#
# ✔ IOC ingestion from MalwareBazaar
# ✔ Shodan monitoring
# ✔ HIBP breach monitoring
# ✔ Automated weekly recon scans
